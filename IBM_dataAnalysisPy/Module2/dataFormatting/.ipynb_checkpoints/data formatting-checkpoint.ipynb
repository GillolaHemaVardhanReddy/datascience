# %%
import pandas as pd
import numpy as np
df = pd.read_csv("automobile.csv")
df.head()
# Out:
#    Unnamed: 0  symboling normalized-losses         make fueltype aspiration
# 0           0          3                 ?  alfa-romero      gas        std  \
# 1           1          3                 ?  alfa-romero      gas        std
# 2           2          1                 ?  alfa-romero      gas        std
# 3           3          2               164         audi      gas        std
# 4           4          2               164         audi      gas        std
#
#   no-of-doors   body-style drive-wheels engine-location  ...  engine-size
# 0         two  convertible          rwd           front  ...          130  \
# 1         two  convertible          rwd           front  ...          130
# 2         two    hatchback          rwd           front  ...          152
# 3        four        sedan          fwd           front  ...          109
# 4        four        sedan          4wd           front  ...          136
#
# ...

# %%
# convert city-mpg to city-L/100km converting mpg to L/100km
df["city-mpg"] = 235/df["city-mpg"]
df.rename(columns={"city-mpg":"city-L/100km"},inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0  symboling normalized-losses         make fueltype aspiration
# 0           0          3                 ?  alfa-romero      gas        std  \
# 1           1          3                 ?  alfa-romero      gas        std
# 2           2          1                 ?  alfa-romero      gas        std
# 3           3          2               164         audi      gas        std
# 4           4          2               164         audi      gas        std
#
#   no-of-doors   body-style drive-wheels engine-location  ...  engine-size
# 0         two  convertible          rwd           front  ...          130  \
# 1         two  convertible          rwd           front  ...          130
# 2         two    hatchback          rwd           front  ...          152
# 3        four        sedan          fwd           front  ...          109
# 4        four        sedan          4wd           front  ...          136
#
# ...

# %%
# check if there is wrong datatype assignment to any feature
df["price"].tail(2)
# here dtype for this price is object but it must be integer/float
# Out:
# 203    22470
# 204    22625
# Name: price, dtype: object

# %%
# converting one data type to another of given feature
# before convertig remove those with missing values 
df.replace(np.nan,)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 2
#       1 # converting one data type to another of given feature
# ----> 2 df.price = df["price"].astype(int)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325     return self._constructor(new_data).__finalize__(self, method="astype")
#    6327 # GH 33113: handle empty frame or series
#
# ...
